# %% [markdown]
# ### Import Library

# %%
from Pegasus import *

# %% [markdown]
# ### Generate Data

# %%
filename = 'Database.csv'
N = 10000
data = gen_popn(filename,pop_size = N,c_min = 5,u_min = 10)
sortdata = sort_data(filename = filename)

# %% [markdown]
# ### What is the Budget required to help p agents

# %%
p = 9000
scheme = 'Agents Aided Limit'
print(f"We need a budget of {subsidy(p)} units to help {p} agents")
# Out:
# We need a budget of 2213607.2508214936 units to help 9000 agents

# %% [markdown]
# ### How many agents can we help with given Budget

# %%
Budget = 50000
scheme = 'Budget Limit'
print(f"With a budget of {Budget} units we can help {HowManyBenefit(Budget)} agents")
# Out:
# With a budget of 50000 units we can help 3394 agents

# %% [markdown]
# ### Statistics to set RP Limit

# %%
RP_Limit = 0.7
scheme = 'RP Limit'
print(f"To achieve an RP Limit of {RP_Limit}, we need a Budget of {setrplimit(RP_Limit)}")
# Out:
# To achieve an RP Limit of 0.7, we need a Budget of 37067.18016969307 units and can help 3022 agents

# %% [markdown]
# ### View Results

# %%
viewresults()

# %%
statistics(scheme,show_subsidy = False)
# Out:
# Scheme : Budget Limit
# Percentage population helped : 33.94%
# Budget required : 49955.199 units
# RP Limit : 0.661046626994865
